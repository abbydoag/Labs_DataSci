# %% [markdown]
# # Laboratorio 3. Entrenamiento y Tuneo de Modelos
#
# Fabian Prado Dluzniewski 23427
#
# Abby Donis 22440
#
# Hansel Lopez 19026
#
# Este notebook cubre los ejercicios 7,8 y 9.

# %%
import time
import random
import json
from pathlib import Path
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image, ImageEnhance, ImageFilter, ImageOps

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, Dataset
from torchvision import transforms
from torchvision.transforms import functional as F

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# %matplotlib inline
torch.manual_seed(42)
np.random.seed(42)

# %%
#config

DISPOSITIVO = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"dispositivo: {DISPOSITIVO}")

DIR_DATOS =Path("./data")
DIR_PROC = DIR_DATOS/"procesado"
DIR_MODELOS = DIR_DATOS/"modelos"
DIR_MODELOS.mkdir(exist_ok=True)
DIR_FOTOS = Path("./team_datos")
DIR_FOTOS.mkdir(exist_ok=True)

#normalizacion
normalizacion = np.load(DIR_PROC/"normalizacion.npz", allow_pickle=True)
MEDIA, DESV = normalizacion["media"], normalizacion["desv"]
CLASES = list(normalizacion["clases"])
LADO = int(normalizacion["lado"])
N_CLASES = len(CLASES)
print(f"Clases: {N_CLASES}\tentrada{3}x{LADO}x{LADO}")

def carga_datos(grupo):
    d = np.load(DIR_PROC/f"{grupo}.npz")
    return d["X"], d["y"]

X_train, y_train = carga_datos("train")
X_val,y_val = carga_datos("val")
X_test, y_test = carga_datos("test")

print(f"Train: {X_train.shape}, {y_train.shape}")
print(f"Validacion: {X_val.shape}, {y_val.shape}")
print(f"Test: {X_test.shape}, {y_test.shape}")
# Out:
# dispositivo: cpu
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 14
#      10 DIR_FOTOS = Path("./team_datos")
#      11 DIR_FOTOS.mkdir(exist_ok=True)
#      12
#      13 #normalizacion
# ---> 14 normalizacion = np.load(DIR_PROC/"normalizacion.npz", allow_pickle=True)
#      15 MEDIA, DESV = normalizacion["media"], normalizacion["desv"]
#      16 CLASES = list(normalizacion["clases"])
#      17 LADO = int(normalizacion["lado"])
#
# File c:\Users\abbyd\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\procesado\\normalizacion.npz'

# %% [markdown]
# ### 7. Transformaciones

# %% [markdown]
# ### 8. Mejor modelo con datos propios

# %% [markdown]
# ### 9. Reflexiones de accesibilidad y sesgo
#
# Las limitantes del dataset incluyen que algunas letras conllevan movimiento tal como el caso de las letras J y Z, además de que es un dataset con una escalada de datos considerada pequeña en comparación con otros. Además, la falta de variedad de tonos de piel de los participantes, edades (influyendo el tamaño y articulación de las manos) y ambiente controlado pueden afectar la exactitud del modelo en contextos de la vida real.
# Haría falta resolver el estudio de letras y señas que representan palabras o contextos para dar una base de datos más amplia y realista, incluyendo por supuesto una mayor variedad en los sujetos de prueba.
#
#
#
# **Nota**: Debido a limitaciones de hardware el procesamiento de los datos llevó mucho más tiempo de lo esperado, por lo que se subiera el script incompleto pero el git si contará con todos los incisos que hagan falta.
